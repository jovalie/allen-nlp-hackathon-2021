# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_PATH = '/content/drive/MyDrive/Colab Notebooks/Allen_NLP_hackathon'
predicted_nyt_data = os.path.join(ROOT_PATH, 'Data', 'predicted_sentences.csv')

# %%
anger_data = pd.read_csv(predicted_nyt_data)

# %%
anger_data_fatma = anger_data[:250]

# %%
anger_data_fatma
# Out:
#      Unnamed: 0  ... sadness_prediciton
# 0        196475  ...           0.609345
# 1        656375  ...           0.647025
# 2        295809  ...           0.582916
# 3         58031  ...           0.588857
# 4        555198  ...           0.625729
# ..          ...  ...                ...
# 245      594099  ...           0.602399
# 246      158207  ...           0.598898
# 247       72023  ...           0.597157
# 248      283741  ...           0.612410
# 249      269616  ...           0.604598
#
# [250 rows x 4 columns]

# %%
anger_data_Joan = anger_data[250:500]

# %%
anger_data_Joan
# Out:
#      Unnamed: 0  ... sadness_prediciton
# 250      469231  ...           0.658512
# 251      207128  ...           0.597345
# 252      114472  ...           0.600266
# 253      498119  ...           0.617919
# 254      341518  ...           0.600264
# ..          ...  ...                ...
# 495      302583  ...           0.637620
# 496      364930  ...           0.587406
# 497      615652  ...           0.602838
# 498      431221  ...           0.615731
# 499      531958  ...           0.643978
#
# [250 rows x 4 columns]

# %%
anger_data_grace = anger_data[500:750]

# %%
anger_data_yonu = anger_data[750:1000]

# %%
anger_data_fatma.to_csv(os.path.join(ROOT_PATH, 'Data', 'nyt_predicted_sentences_fatma.csv'))

# %%
anger_data_Joan.to_csv(os.path.join(ROOT_PATH, 'Data', 'nyt_predicted_sentences_joan.csv'))

# %%
anger_data_grace.to_csv(os.path.join(ROOT_PATH, 'Data', 'nyt_predicted_sentences_grace.csv'))

# %%
anger_data_yonu.to_csv(os.path.join(ROOT_PATH, 'Data', 'nyt_predicted_sentences_vashaka.csv'))
