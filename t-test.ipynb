# %%
import os
import pandas as pd
import spacy


# Library setups
from google.colab import drive
drive.mount('/content/drive')

nlp = spacy.load("en_core_web_sm")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Colab Notebooks/Allen_NLP_hackathon
# Out:
# /content/drive/.shortcut-targets-by-id/18wIy9U4zK_LdoQmnfHm1GL3Xzxy8Ki6V/Allen_NLP_hackathon

# %%
df_seeds = pd.read_csv('Data/seeds.csv')

# %%
df_seeds
# Out:
#                    Category                                              Seeds
# 0   european_american_names  [Adam, Harry, Josh, Roger, Alan, Frank, Justin...
# 1    african_american_names  [Alonzo, Jamel, Theo, Alphonse, Jerome, Leroy,...
# 2               names_asian  [cho, wong, tang, huang, chu, chung, ng, wu, l...
# 3               names_black  [harris, robinson, howard, thompson, moore, wr...
# 4             names_chinese  [chung, liu, wong, huang, ng, hu, chu, chen, l...
# 5            names_hispanic  [ruiz, alvarez, vargas, castillo, gomez, soto,...
# 6                     black    [black, african, black, africa, africa, africa]
# 7                 caucasian  [caucasian, caucasian, white, america, america...
# 8                     asian           [asian, asian, asian, asia, china, asia]
# 9                male_names  [John, Paul, Mike, Kevin, Steve, Greg, Jeff, B...
# 10             female_names  [Amy, Joan, Lisa, Sarah, Diana, Kate, Ann, Donna]
# 11        androgynous_names  [Kelly, Tracy, Jamie, Jackie, Jesse, Courtney,...
# 12                     male       [brother, male, man, boy, son, he, his, him]
# 13                   female  [sister, female, woman, girl, daughter, she, h...
# 14                      jew            [judaism, jew, synagogue, torah, rabbi]
# 15                christian   [christianity, christian, church, bible, priest]
# 16                   muslim               [islam, muslim, mosque, quran, imam]

# %% [markdown]
# ## T-test

# %%
from scipy.stats import ttest_ind

# %% [markdown]
# ## Plot
