# %% [markdown]
# ## Loading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Allen_NLP_hackathon/Data/
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/18wIy9U4zK_LdoQmnfHm1GL3Xzxy8Ki6V/Allen_NLP_hackathon/Data
# data/  Emotion_Regression/  Equity-Evaluation-Corpus.zip  nyt-h/  nyt-h.tar.bz2

# %%
# extract the data
# !tar jxvf nyt-h.tar.bz2
# Out:
# data/
# data/dev.json
# data/bag_label2id.json
# data/train_nonna.json
# data/rel2id.json
# data/test.json
# data/na_rest.json
# data/na_train.json

# %%
# %cd data
# %ls
# Out:
# [Errno 2] No such file or directory: 'data'
# /content/drive/.shortcut-targets-by-id/18wIy9U4zK_LdoQmnfHm1GL3Xzxy8Ki6V/Allen_NLP_hackathon/Data/data
# bag_label2id.json  na_rest.json   rel2id.json  train_nonna.json
# dev.json           na_train.json  test.json

# %% [markdown]
# ## Extract Sentences

# %%
import json
import csv
import pandas as pd

# %%
files = [
  # "bag_label2id.json",
  # "rel2id.json",
  "na_train.json",
  "na_rest.json",
  "train_nonna.json",
  "dev.json",
  "test.json"
]

# %%
for file_name in files:
  df = pd.read_json(file_name, lines=True)
  s = df[["sentence"]]
  s.to_csv('sentences.csv', index=False, header=False, mode='a')   

  # check to make sure csv is growing
  file = 'object.myfilePath'
  file = open("data.csv")
  numline = len(file.readlines())
  print(s.size)
  print("NUMBER OF TOTAL CSV LINES:", numline)
# Out:
# 96831
# NUMBER OF TOTAL CSV LINES: 96831
# 453889
# NUMBER OF TOTAL CSV LINES: 550720
# 96831
# NUMBER OF TOTAL CSV LINES: 647551
# 10262
# NUMBER OF TOTAL CSV LINES: 657813
# 9955
# NUMBER OF TOTAL CSV LINES: 667768
